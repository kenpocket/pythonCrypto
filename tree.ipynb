# %%
import requests
url = 'https://r3kapig.com/assets/js/tree.js'

# %%
response = requests.get(url)
response.encoding = response.apparent_encoding

# %%
with open('a.js', 'w', encoding='utf-8')as fp:
    fp.write(response.text)

# %%
将a.js中的内容格式化，删除不相关代码，剩余内容写入b.json

# %%
file = open('b.json', 'r', encoding='utf-8')
value = []
for i in file:
    if 'label' in i:
        value.append(i)

# %%
value
# Out:
# ['  label: "CRYPTO",\n',
#  '      label: "数学基础",\n',
#  '          label: "基础代数",\n',
#  '              label: "群、环、域"\n',
#  '              label: "分式域、域扩张"\n',
#  '              label: "初等数论"\n',
#  '              label: "整环、代数数域"\n',
#  '          label: "计算数论",\n',
#  '              label: "（扩展）Euclid 算法"\n',
#  '              label: "中国剩余定理"\n',
#  '              label: "连分数"\n',
#  '              label: "Legendre-Jacobi-Kronecker Symbol"\n',
#  '              label: "模 p 平方根（Tonelli-Shanks）"\n',
#  '              label: "模 p 多项式方程（组）求解",\n',
#  '                  label: "Hensel 引理"\n',
#  '                  label: "Resultant"\n',
#  '                  label: "Gröbner basis"\n',
#  '              label: "线性代数 & 格",\n',
#  '                  label: "高斯消元"\n',
#  '                  label: "Hermite & Smith Normal Forms"\n',
#  '                  label: "LLL & BKZ"\n',
#  '                  label: "CVP/SVP/SIS"\n',
#  '                  label: "Babai nearest plane"\n',
# ...

# %%
value = [i.replace('label: "', '').replace('"', '').replace('\n', '') for i in value]

# %%
value
# Out:
# ['  CRYPTO,',
#  '      数学基础,',
#  '          基础代数,',
#  '              群、环、域',
#  '              分式域、域扩张',
#  '              初等数论',
#  '              整环、代数数域',
#  '          计算数论,',
#  '              （扩展）Euclid 算法',
#  '              中国剩余定理',
#  '              连分数',
#  '              Legendre-Jacobi-Kronecker Symbol',
#  '              模 p 平方根（Tonelli-Shanks）',
#  '              模 p 多项式方程（组）求解,',
#  '                  Hensel 引理',
#  '                  Resultant',
#  '                  Gröbner basis',
#  '              线性代数 & 格,',
#  '                  高斯消元',
#  '                  Hermite & Smith Normal Forms',
#  '                  LLL & BKZ',
#  '                  CVP/SVP/SIS',
#  '                  Babai nearest plane',
#  '              椭圆曲线,',
#  '                  群结构（加法公式，点的数量）',
#  '                  不同曲线形式及相互转换',
#  '                  除子',
#  '                  Complex Multiplication',
#  '                  Weil & Tate pairing',
#  '              整数分解,',
# ...

# %%
for i in value:
    print(i.count(' ')//value[0].count(' '))
# Out:
# 1
# 3
# 5
# 7
# 7
# 7
# 7
# 5
# 7
# 7
# 7
# 7
# 8
# 8
# 9
# 9
# 9
# 8
# 9
# 11
# 10
# 9
# 10
# 7
# 9
# 9
# 9
# 9
# 10
# 7
# 9
# 9
# 9
# 9
# 9
# 9
# 7
# 9
# 9
# 9
# 9
# 7
# 9
# 9
# 9
# 9
# 9
# 11
# 11
# 9
# 11
# 11
# 3
# 7
# 5
# 5
# 5
# 6
# 3
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 3
# 5
# 7
# 7
# 7
# 7
# 5
# 7
# 7
# 7
# 7
# 7
# 7
# 5
# 7
# 7
# 7
# 7
# 3
# 5
# 7
# 7
# 7
# 7
# 7
# 5
# 7
# 7
# 7
# 7
# 7
# 7
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 3
# 5
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 5
# 8
# 7
# 7
# 7
# 5
# 5
# 5
# 3
# 5
# 7
# 7
# 7
# 7
# 7
# 7
# 5
# 5
# 5
# 7
# 9
# 7
# 5
# 7
# 7
# 3
# 5
# 7
# 9
# 7
# 5
# 5
# 7
# 7
# 6
# 5
# 8
# 5
# 7
# 3
# 5
# 7
# 7
# 7
# 7
# 7
# 5
# 7
# 7
# 7
# 7
# 8
# 8
# 7
# 10
# 10
# 5
# 7
# 7
# 7
# 5
# 3
# 5
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 8
# 7
# 5
# 3
# 5
# 5
# 5
# 5
# 5
# 1
# 3
# 5
# 7
# 7
# 7
# 7
# 8
# 7
# 8
# 7
# 7
# 8
# 8
# 7
# 5
# 7
# 9
# 9
# 9
# 9
# 8
# 7
# 3
# 5
# 7
# 5
# 7
# 7
# 5
# 7
# 10
# 9
# 10
# 10
# 9
# 9
# 9
# 9
# 10
# 9
# 7
# 9
# 7
# 9
# 10
# 9
# 12
# 9
# ...

# %%
value[0].count(' ')
# Out:
# 2

# %%
value[1].count(' ')
# Out:
# 6
